# %% [markdown]
# ## Example Notebook for PulseBlaster using QCoDes

# %% [markdown]
# #### Imports and connecting to the instrument

# %% [markdown]
# ##### if you change the code in the pulseblaster_d.py file, restart the kernel and rerun all blocks

# %%
from pulseblaster_d import pulseblasterd #import driver

# %%
pulser = pulseblasterd('pulseblaster') #create an pulseblaster object

# %% [markdown]
# ### TODO 1: Program a Sample Pulse

# %% [markdown]
# #### 1. Open pulseblaster_d.py file and go TODO 1
# #### 2. Run the next block and use an oscillioscope to confirm the output and answer the questions in the Lab Handout

# %%
pulser.program_samplePulse() #will set the sample pulse sequence that you wrote
pulser.start() #will start running the pulse sequence on the programmed ports

# %%
pulser.stop()               #tells the pulseblaster to stop outputting all signals
